# %%
print('Hi!')
import numpy as np
import pandas as pd
print(pd.__version__)

data = pd.Series([0.25, 0.5, 0.75, 1.0])
data
# Out:
# Hi!
# 2.3.3
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data[1]
# Out:
# np.float64(0.5)

# %%
data[1:3]
# Out:
# 1    0.50
# 2    0.75
# dtype: float64

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']
# Out:
# np.float64(0.5)

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=[2, 5, 3, 7])
data
# Out:
# 2    0.25
# 5    0.50
# 3    0.75
# 7    1.00
# dtype: float64

# %%
data[5]
# Out:
# np.float64(0.5)

# %%
population_dict = {'California': 35332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
population = pd.Series(population_dict)
population
# Out:
# California    35332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population['California']
# Out:
# np.int64(35332521)

# %%
population['California':'New York']
# Out:
# California    35332521
# Texas         26448193
# New York      19651127
# dtype: int64

# %%
# pd.Series(data, index=index)

pd.Series([2, 4, 6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
pd.Series(5, index=[100, 200, 300])
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %%
pd.Series({2: 'a', 1:'b', 3:'c'})
# Out:
# 2    a
# 1    b
# 3    c
# dtype: object

# %%
pd.Series({2: 'a', 1:'b', 3:'c'}, index=[2, 3])
# Out:
# 2    a
# 3    c
# dtype: object

# %%
aria_dict =  {'California': 423967,
              'Texas': 695662,
              'New York': 141297,
              'Florida': 170312,
              'Illinois': 149995}
area = pd.Series(aria_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({'population': population, 'area': area})
states
# Out:
#             population    area
# California    35332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
states.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
states.columns
# Out:
# Index(['population', 'area'], dtype='object')

# %% [markdown]
# Object DataFrame as special dictionary

# %%
states['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %% [markdown]
# Create DataFrame objects

# %% [markdown]
# From one object Series

# %%
pd.DataFrame(population, columns=['population'])
# Out:
#             population
# California    35332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135

# %% [markdown]
# From a list of dictionary

# %%
data = [{'a': i, 'b': 2 * i} for i in range(3)]
pd.DataFrame(data)
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %%
pd.DataFrame([{'a': 1, 'b': 2}, {'b': 3, 'c': 4}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %% [markdown]
# NaN - Not a number

# %% [markdown]
# From a dictionary of Series objects

# %%
pd.DataFrame({'population': population, 'area': area})
# Out:
#             population    area
# California    35332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %% [markdown]
# From a two-dimensional NumPy array

# %%
pd.DataFrame(np.random.rand(3, 2),
             columns=['foo', 'bar'],
             index=['a', 'b', 'c'])
# Out:
#         foo       bar
# a  0.580176  0.855174
# b  0.551384  0.856431
# c  0.807215  0.078055

# %% [markdown]
# The Index object from the Pandas library

# %%
ind = pd.Index([2, 3, 5, 7, 11])
ind
# Out:
# Index([2, 3, 5, 7, 11], dtype='int64')

# %% [markdown]
# Index object as an immutable array

# %%
print(ind[1])
print(ind[::2])
print(ind.size, ind.shape, ind.ndim, ind.dtype)
# Out:
# 3
# Index([2, 5, 11], dtype='int64')
# 5 (5,) 1 int64

# %%
# ind[1] = 0

# %% [markdown]
# Index as an ordered set

# %%
indA = pd.Index([1, 3, 5, 7, 9])
indB = pd.Index([2, 3, 5, 7, 11])

# %%
indA.intersection(indB) # intesection
# Out:
# Index([3, 5, 7], dtype='int64')

# %%
indA.union(indB) # union
# Out:
# Index([1, 2, 3, 5, 7, 9, 11], dtype='int64')

# %%
indA.symmetric_difference(indB) # symmetric difference
# Out:
# Index([1, 2, 9, 11], dtype='int64')

# %% [markdown]
# INDEXING AND DATA SELECTION

# %% [markdown]
# *** Retrieving data from a Series object ***

# %% [markdown]
# Series object as a dictionary

# %%
# import pandas as pd
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']
# Out:
# np.float64(0.5)

# %%
'a' in data
# Out:
# True

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
list(data.items())
# Out:
# [('a', 0.25), ('b', 0.5), ('c', 0.75), ('d', 1.0)]

# %%
data['e'] = 1.25
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.25
# dtype: float64

# %% [markdown]
# Series object as one-dimentional array

# %%
# slice by means of an explicit index
data['a': 'c']
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %%
# slice by means of an implicite integer index
data[0: 2]
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
# masking
data[(data > 0.3) & (data < 0.8)]
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
# "fancy" indexing
data[['a', 'e']]
# Out:
# a    0.25
# e    1.25
# dtype: float64

# %% [markdown]
# Indexers: loc, iloc and ix

# %%
data = pd.Series(['a', 'b', 'c'], index=[1, 3, 5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
# using an explicite index under indexing
data[1]
# Out:
# 'a'

# %%
# using an implicite index under a slice
data[1: 3]
# Out:
# 3    b
# 5    c
# dtype: object

# %%
data.loc[1]
# Out:
# 'a'

# %%
data.loc[1: 3]
# Out:
# 1    a
# 3    b
# dtype: object

# %%
data.iloc[1]
# Out:
# 'b'

# %%
data.iloc[1: 3]
# Out:
# 1    0.50
# 2    0.75
# dtype: float64

# %% [markdown]
# *** Retrieving Data from a DataFrame object ***

# %% [markdown]
# DataFrame object as a dictionary

# %%
area = pd.Series({'California': 423967,
                  'Texas': 695662,
                  'New York': 141297,
                  'Florida': 170312,
                  'Illinois': 149995})

pop =  pd.Series({'California': 35332521,
                  'Texas': 26448193,
                  'New York': 19651127,
                  'Florida': 19552860,
                  'Illinois': 12882135})

data = pd.DataFrame({'area': area, 'pop': pop})
data
# Out:
#               area       pop
# California  423967  35332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.area is data['area']
# Out:
# True

# %%
data.pop is data['pop']
# Out:
# False

# %%
data['density'] = data['pop'] / data['area']
data
# Out:
#               area       pop     density
# California  423967  35332521   83.337904
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %% [markdown]
# DataFrame object as a two-dimentional array

# %%
data.values
# Out:
# array([[4.23967000e+05, 3.53325210e+07, 8.33379037e+01],
#        [6.95662000e+05, 2.64481930e+07, 3.80187404e+01],
#        [1.41297000e+05, 1.96511270e+07, 1.39076746e+02],
#        [1.70312000e+05, 1.95528600e+07, 1.14806121e+02],
#        [1.49995000e+05, 1.28821350e+07, 8.58837628e+01]])

# %%
data.T
# Out:
#            California         Texas      New York       Florida      Illinois
# area     4.239670e+05  6.956620e+05  1.412970e+05  1.703120e+05  1.499950e+05
# pop      3.533252e+07  2.644819e+07  1.965113e+07  1.955286e+07  1.288214e+07
# density  8.333790e+01  3.801874e+01  1.390767e+02  1.148061e+02  8.588376e+01

# %%
data.values[0]
# Out:
# array([4.23967000e+05, 3.53325210e+07, 8.33379037e+01])

# %%
data['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.iloc[:3, :2]
# Out:
#               area       pop
# California  423967  35332521
# Texas       695662  26448193
# New York    141297  19651127

# %%
data.loc[:'New York', :'pop']
# Out:
#               area       pop
# California  423967  35332521
# Texas       695662  26448193
# New York    141297  19651127

# %%
data.loc[data.density > 100, ['pop', 'density']]
# Out:
#                pop     density
# New York  19651127  139.076746
# Florida   19552860  114.806121

# %%
data.iloc[0, 2] = 90
data
# Out:
#               area       pop     density
# California  423967  35332521   90.000000
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %% [markdown]
# Additional sintax for indexing

# %%
data['Florida':'Illinois']
# Out:
#             area       pop     density
# Florida   170312  19552860  114.806121
# Illinois  149995  12882135   85.883763

# %%
data[1:3]
# Out:
#             area       pop     density
# Texas     695662  26448193   38.018740
# New York  141297  19651127  139.076746

# %%
data[data.density > 100]
# Out:
#             area       pop     density
# New York  141297  19651127  139.076746
# Florida   170312  19552860  114.806121
