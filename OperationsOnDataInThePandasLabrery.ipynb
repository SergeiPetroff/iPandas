# %% [markdown]
# OPERATION ON DATA IN THE PANDAS LABRERY

# %% [markdown]
# *** Universal fanctions: save index ***

# %%
import pandas as pd
import numpy as np

# %%
rng = np.random.RandomState(42)
ser = pd.Series(rng.randint(0, 10, 4))
ser
# Out:
# 0    6
# 1    3
# 2    7
# 3    4
# dtype: int64

# %%
df = pd.DataFrame(rng.randint(0, 10, (3, 4)),
                  columns=['A', 'B', 'C', 'D'])
df
# Out:
#    A  B  C  D
# 0  1  9  3  7
# 1  6  8  7  4
# 2  1  4  7  9

# %%
np.exp(ser)
# Out:
# 0     403.428793
# 1      20.085537
# 2    1096.633158
# 3      54.598150
# dtype: float64

# %%
np.sin(df * np.pi / 4)
# Out:
#           A             B         C             D
# 0  0.707107  7.071068e-01  0.707107 -7.071068e-01
# 1 -1.000000 -2.449294e-16 -0.707107  1.224647e-16
# 2  0.707107  1.224647e-16 -0.707107  7.071068e-01

# %% [markdown]
# *** Universal fanctions: level index ***

# %% [markdown]
# Leveling indexes in Series objects

# %%
area = pd.Series({'Alaska': 1723337, 'Texas': 695662, 'California': 423967}, name = 'area')
population = pd.Series({'California': 38332521, 'Texas': 26448193, 'New York': 19651127}, name = 'population')

# %%
population / area
# Out:
# Alaska              NaN
# California    90.413926
# New York            NaN
# Texas         38.018740
# dtype: float64

# %%
area.index.union(population.index)
# Out:
# Index(['Alaska', 'California', 'New York', 'Texas'], dtype='object')

# %%
A = pd.Series([2, 4, 6], index=[0, 1, 2])
B = pd.Series([1, 3, 5], index=[1, 2, 3])
A + B
# Out:
# 0    NaN
# 1    5.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
A.add(B, fill_value=0)
# Out:
# 0    2.0
# 1    5.0
# 2    9.0
# 3    5.0
# dtype: float64

# %% [markdown]
# Leveling indexes in DataFrame objects

# %%
A = pd.DataFrame(rng.randint(0, 20, (2, 2)),
                 columns=list('AB'))
A
# Out:
#     A   B
# 0  12   8
# 1  14  12

# %%
B = pd.DataFrame(rng.randint(0, 10, (3, 3)),
                 columns=list('BAC'))
B
# Out:
#    B  A  C
# 0  0  8  6
# 1  8  7  0
# 2  7  7  2

# %%
A + B
# Out:
#       A     B   C
# 0  20.0   8.0 NaN
# 1  21.0  20.0 NaN
# 2   NaN   NaN NaN

# %%
A.stack()
# Out:
# 0  A    12
#    B     8
# 1  A    14
#    B    12
# dtype: int64

# %%
fill = A.stack().mean()
A.add(B, fill_value=fill)
# Out:
#       A     B     C
# 0  20.0   8.0  17.5
# 1  21.0  20.0  11.5
# 2  18.5  18.5  13.5

# %% [markdown]
# *** Universal fanctions: make operations between DataFrame and Series objects ***

# %%
A = rng.randint(10, size=(3, 4))
A
# Out:
# array([[6, 0, 3, 3],
#        [4, 6, 6, 3],
#        [6, 2, 5, 1]])

# %%
A - A[0]
# Out:
# array([[ 0,  0,  0,  0],
#        [-2,  6,  3,  0],
#        [ 0,  2,  2, -2]])

# %%
df = pd.DataFrame(A, columns=list('QRST'))
df - df.iloc[0]
# Out:
#    Q  R  S  T
# 0  0  0  0  0
# 1 -2  6  3  0
# 2  0  2  2 -2

# %%
df.subtract(df['R'], axis=0)
# Out:
#    Q  R  S  T
# 0  6  0  3  3
# 1 -2  0  0 -3
# 2  4  0  3 -1

# %%
halfrow = df.iloc[0, ::2]
halfrow
# Out:
# Q    6
# S    3
# Name: 0, dtype: int64

# %%
df - halfrow
# Out:
#      Q   R    S   T
# 0  0.0 NaN  0.0 NaN
# 1 -2.0 NaN  3.0 NaN
# 2  0.0 NaN  2.0 NaN
